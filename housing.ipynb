# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
# Out:
# C:\Users\Ademo\AppData\Local\Temp\ipykernel_9812\3005925559.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
housing_data = pd.read_csv("california_housing_sklearn.csv")

# %%
housing_data.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  SalePrice
# 0    -122.23      4.526
# 1    -122.22      3.585
# 2    -122.24      3.521
# 3    -122.25      3.413
# 4    -122.25      3.422

# %%
housing_data.describe().transpose()
# Out:
#               count         mean          std         min         25%  \
# MedInc      20640.0     3.870671     1.899822    0.499900    2.563400
# HouseAge    20640.0    28.639486    12.585558    1.000000   18.000000
# AveRooms    20640.0     5.429000     2.474173    0.846154    4.440716
# AveBedrms   20640.0     1.096675     0.473911    0.333333    1.006079
# Population  20640.0  1425.476744  1132.462122    3.000000  787.000000
# AveOccup    20640.0     3.070655    10.386050    0.692308    2.429741
# Latitude    20640.0    35.631861     2.135952   32.540000   33.930000
# Longitude   20640.0  -119.569704     2.003532 -124.350000 -121.800000
# SalePrice   20640.0     2.068558     1.153956    0.149990    1.196000
#
#                     50%          75%           max
# MedInc         3.534800     4.743250     15.000100
# HouseAge      29.000000    37.000000     52.000000
# AveRooms       5.229129     6.052381    141.909091
# AveBedrms      1.048780     1.099526     34.066667
# ...

# %%
housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
#  8   SalePrice   20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
#sns.pairplot(housing_data)

# %%
housing_data.corr()["SalePrice"].drop("SalePrice").plot(kind="bar")
# Out:
# <Axes: >

# %%
housing_data.describe().transpose()
# Out:
#               count         mean         std         min         25%  \
# MedInc      19904.0     3.810335    1.749102    0.499900    2.555600
# HouseAge    19904.0    28.965434   12.448558    1.000000   19.000000
# AveRooms    19904.0     5.256985    1.204104    0.846154    4.427143
# AveBedrms   19904.0     1.066214    0.128595    0.333333    1.004984
# Population  19904.0  1349.557174  823.443486    3.000000  792.000000
# AveOccup    19904.0     2.902994    0.719144    0.750000    2.427388
# Latitude    19904.0    35.629234    2.132912   32.540000   33.930000
# Longitude   19904.0  -119.584299    2.003329 -124.350000 -121.810000
# SalePrice   19904.0     2.058323    1.140855    0.149990    1.188000
#
#                     50%          75%          max
# MedInc         3.519200     4.713700    11.999300
# HouseAge      29.000000    37.000000    52.000000
# AveRooms       5.201138     5.994914     9.979167
# AveBedrms      1.047744     1.097288     3.411111
# ...

# %%
sns.displot(housing_data["MedInc"])

# %%
housing_data[housing_data["MedInc"]>12]
# Out:
# Empty DataFrame
# Columns: [MedInc, HouseAge, AveRooms, AveBedrms, Population, AveOccup, Latitude, Longitude, SalePrice]
# Index: []

# %%
housing_data = housing_data[housing_data["MedInc"]<12]

# %%
sns.displot(housing_data["AveRooms"])

# %%
housing_data[housing_data["AveRooms"]>10]
# Out:
#        MedInc  HouseAge   AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1023   2.2417      15.0  10.515306   2.372449       573.0  2.923469     38.72
# 1024   3.1500      16.0  29.852941   5.323529       202.0  1.980392     38.52
# 1030   3.0125      15.0  10.168591   2.057737      1103.0  2.547344     38.55
# 1102   2.4028      17.0  31.777778   9.703704        47.0  1.740741     40.06
# 1233   3.7500      10.0  16.847534   3.237668       546.0  2.448430     38.23
# ...       ...       ...        ...        ...         ...       ...       ...
# 20093  2.0625      37.0  24.669118   4.897059       338.0  2.485294     38.12
# 20094  2.1250      26.0  37.063492   7.185185       416.0  2.201058     38.19
# 20110  3.2589       9.0  11.458508   2.056161      2811.0  2.356245     37.84
# 20112  4.0833      18.0  11.536585   2.804878        88.0  2.146341     37.85
# 20113  3.4861      17.0  17.300000   6.500000        51.0  2.550000     37.94
#
#        Longitude  SalePrice
# ...

# %%
housing_data = housing_data[housing_data["AveRooms"]<10]

# %%
sns.displot(housing_data["Population"])

# %%
housing_data[housing_data["Population"]>5000]
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 570    7.6110       5.0  6.855776   1.061442      7427.0  2.732524     37.72
# 576    7.2634      12.0  7.133034   1.018934      5781.0  2.880419     37.77
# 780    3.8171      18.0  5.119733   1.043679      5613.0  2.884378     37.63
# 799    2.5158      22.0  4.006152   1.036227      5436.0  3.715653     37.64
# 864    5.8322      14.0  5.689849   1.051282      8117.0  2.851071     37.57
# ...       ...       ...       ...        ...         ...       ...       ...
# 20529  2.9605      12.0  4.915341   1.022451      5633.0  2.634705     38.55
# 20530  3.1371      11.0  5.070223   1.015530      7984.0  2.695476     38.57
# 20544  2.0650      23.0  4.803493   1.013646      6330.0  3.455240     38.55
# 20563  3.1250       9.0  5.148007   1.119593      6837.0  2.899491     38.67
# 20629  2.0943      28.0  5.519802   1.020902      6912.0  3.801980     39.12
#
#        Longitude  SalePrice
# ...

# %%
housing_data = housing_data[housing_data["Population"]<5000]

# %%
sns.displot(housing_data["AveOccup"])

# %%
housing_data[housing_data["AveOccup"]>6]
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population   AveOccup  Latitude  \
# 91     0.8668      52.0  2.443182   0.988636       904.0  10.272727     37.80
# 270    3.8750      33.0  3.021277   0.659574       575.0  12.234043     37.78
# 460    1.4012      52.0  3.105714   1.060000      3337.0   9.534286     37.87
# 1039   4.3029      16.0  6.090592   1.121951      4930.0  17.177700     38.42
# 1067   3.4191      52.0  4.530612   0.816327      1107.0  11.295918     39.73
# ...       ...       ...       ...        ...         ...        ...       ...
# 20297  2.7250      32.0  5.992395   1.133080      3490.0   6.634981     34.15
# 20311  2.0368      37.0  5.662651   1.265060       522.0   6.289157     34.17
# 20324  3.5625      31.0  4.386905   0.869048      1436.0   8.547619     34.25
# 20352  4.0208       8.0  2.500000   0.625000       309.0  19.312500     34.22
# 20527  1.4653       7.0  3.525794   1.017857      4479.0   8.886905     38.54
#
#        Longitude  SalePrice
# ...

# %%
housing_data = housing_data[housing_data["AveOccup"]<6]

# %%
housing_data.shape
# Out:
# (19904, 9)

# %%
### Data only lost 3.6% of the entire data after clean-up
19904/20640 *(100)
# Out:
# 96.43410852713178

# %%
housing_data.corr()["SalePrice"].drop("SalePrice").plot(kind="bar")
# Out:
# <Axes: >

# %%
sns.scatterplot(x="SalePrice", y="MedInc",data=housing_data)
# Out:
# <Axes: xlabel='SalePrice', ylabel='MedInc'>

# %%
sns.scatterplot(x="SalePrice", y="AveOccup",data=housing_data)
# Out:
# <Axes: xlabel='SalePrice', ylabel='AveOccup'>

# %%
X = housing_data.drop("SalePrice", axis=1)
y = housing_data["SalePrice"]

# %% [markdown]
# # MACHINE LEARNING PART
